# %% [markdown]
# <center><img src="https://i.imgur.com/zRrFdsf.png" width="700"></center>
#
#
# # Practical situations using spatial operations....and more

# %% [markdown]
# We will finish the second part of our course with some interesting situations to solve.
#
# 1. We will find a location for some gas stations, given that the city council has decided that no gas station has to e located near a school by less than 100 meters. See [**here**](gasandschools.html)
#
# 2. We will make a decision on how much to charge for a house unit. You will use the neighborhood as the reference. See [**here**](airbnb.html)
#
# 3. Similar to the previous one, we will decide if a neighborhood is safe enough to buy a house. See [**here**](crime.html)

# %% [markdown]
# Some installations needed:
# * pysal: Important library that makes easy complex spatial analysis
# * openpyxl: a small function to open excel files, and which is needed by pandas.
# * geopandas: as usual
# * pandas: as usual
# * h3: An UBER's library, that divides the whole world inro hexagons.
# * geopy: A library we will use to geocode (get a lan/lot for a _street adsress_)
# * osmnx : to interact with OpenStreet
# * mapclassify: for discretizing variables.
#
# You may check if you have those libraries already installed, like this:

# %%
#!pip show pysal openpyxl geopandas pandas h3 geopy osmnx mapclassify
